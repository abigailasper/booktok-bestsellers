# %%
import requests
from bs4 import BeautifulSoup as BS
import re
import pandas as pd

# %%
URL = 'https://www.goodreads.com/shelf/show/booktok'

response = requests.get(URL)

# %%
response.status_code
# Out:
# 200

# %%
soup = BS(response.text)
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ## get book info from first page

# %%
# https://stackoverflow.com/questions/5041008/how-to-find-elements-by-class
cards = soup.find_all("div", {"class": "elementList"})

# %%
print(cards)
# Out:
# [<div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/32620332-the-seven-husbands-of-evelyn-hugo" title="The Seven Husbands of Evelyn Hugo"><img alt="The Seven Husbands of Evelyn Hugo" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1498169036l/32620332._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/32620332-the-seven-husbands-of-evelyn-hugo">The Seven Husbands of Evelyn Hugo (Hardcover)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/6572605.Taylor_Jenkins_Reid" itemprop="url"><span itemprop="name">Taylor Jenkins Reid</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 629 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.48 —
#                 1,142,139 ratings  —
#                 published 2017
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="1_book_32620332">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="wKZcqlboz3hcGWVgTCkw3qTmRKk0y6C4pPCIl9NdD1SskRpC9DHkoN0gO2AZsJEVspAw960EzZwyEF/D5hoTZg=="/>
# <input id="book_id" name="book_id" type="hidden" value="32620332"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_32620332"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="75A4OPlW65HZe5TzFVxiADplzge+adX0jJRMu+5KxzaDp37QW4/ASVhCyvNAxcPLLBO6WSemuNAadJvv2w3bBA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="1_book_32620332"/>
# <input id="book_id" name="book_id" type="hidden" value="32620332"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# <div class="wtrShelfMenu">
# <ul class="wtrExclusiveShelves">
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="to-read">
# <span class="progressTrigger">Want to Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="currently-reading">
# <span class="progressTrigger">Currently Reading</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# <li><button class="wtrExclusiveShelf" name="name" type="submit" value="read">
# <span class="progressTrigger">Read</span>
# <img alt="saving…" class="progressIndicator" src="https://s.gr-assets.com/assets/loading-trans-ced157046184c3bc7c180ffbfc6825a4.gif"/>
# </button>
# </li>
# </ul>
# </div>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="32620332" data-submit-url="/review/rate/32620332?stars_click=true&amp;wtr_button_id=1_book_32620332" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/27362503-it-ends-with-us" title="It Ends with Us"><img alt="It Ends with Us" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1470427482l/27362503._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/27362503-it-ends-with-us">It Ends with Us (Kindle Edition)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/5430144.Colleen_Hoover" itemprop="url"><span itemprop="name">Colleen Hoover</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 571 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.42 —
#                 1,134,203 ratings  —
#                 published 2016
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="2_book_27362503">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="XYMxfBpDu1aoqklzcz3wXbQ2Pn0e1n0+4XyHcHT6x3AxtHeUuJqQjimTF3MmpFGWokBKI4cZEBp3nFAkQb3bQg=="/>
# <input id="book_id" name="book_id" type="hidden" value="27362503"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_27362503"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="XVibR4lA9z89hSetN+z8Az6isBOQ1N6uA1OJucj3kt0xb92vK5nc57y8ea1idV3IKNTETQkbs4qVs17t/bCO7w=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="2_book_27362503"/>
# <input id="book_id" name="book_id" type="hidden" value="27362503"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="27362503" data-submit-url="/review/rate/27362503?stars_click=true&amp;wtr_button_id=2_book_27362503" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/13623848-the-song-of-achilles" title="The Song of Achilles"><img alt="The Song of Achilles" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1357177533l/13623848._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/13623848-the-song-of-achilles">The Song of Achilles (Paperback)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/176372.Madeline_Miller" itemprop="url"><span itemprop="name">Madeline Miller</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 569 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.40 —
#                 810,324 ratings  —
#                 published 2011
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="3_book_13623848">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="MIvmPwAt4MndP+9yce/uSG/gMBS9fIWe0DURpTE5IMFcvKDXovTLEVwGsXIkdk+DeZZESiSz6LpG1cbxBH488w=="/>
# <input id="book_id" name="book_id" type="hidden" value="13623848"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_13623848"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="wJdZcV5xVKI0dR/21q/GvTz6QXcHhp/+dlynxXOnh3ysoB+Z/Kh/erVMQfaDNmd2Kow1KZ5J8trgvHCRRuCbTg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="3_book_13623848"/>
# <input id="book_id" name="book_id" type="hidden" value="13623848"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="13623848" data-submit-url="/review/rate/13623848?stars_click=true&amp;wtr_button_id=3_book_13623848" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/50623864-the-invisible-life-of-addie-larue" title="The Invisible Life of Addie LaRue"><img alt="The Invisible Life of Addie LaRue" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1584633432l/50623864._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/50623864-the-invisible-life-of-addie-larue">The Invisible Life of Addie LaRue (Hardcover)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/7168230.V_E_Schwab" itemprop="url"><span itemprop="name">V.E. Schwab</span></a>
# </div>
# </span>
#
#
#               (shelved 469 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.23 —
#                 600,335 ratings  —
#                 published 2020
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="4_book_50623864">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="8BnUHh0LbDK5c0OP7IzC5K1ufNAJJw/LCt7bKesTl1mcLpL2v9JH6jhKHY+5FWMvuxgIjpDoYu+cPgx93lSLaw=="/>
# <input id="book_id" name="book_id" type="hidden" value="50623864"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_50623864"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="4pyEoQrfNcP9Z9jeLYSnzcVkcxi5HvRF+Mx5ls/fAN6Oq8JJqAYeG3xeht54HQYG0xIHRiDRmWFuLK7C+pgc7A=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="4_book_50623864"/>
# <input id="book_id" name="book_id" type="hidden" value="50623864"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="50623864" data-submit-url="/review/rate/50623864?stars_click=true&amp;wtr_button_id=4_book_50623864" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/26032825-the-cruel-prince" title="The Cruel Prince (The Folk of the Air, #1)"><img alt="The Cruel Prince (The Folk of the Air, #1)" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1574535986l/26032825._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/26032825-the-cruel-prince">The Cruel Prince (The Folk of the Air, #1)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/25422.Holly_Black" itemprop="url"><span itemprop="name">Holly Black</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 450 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.10 —
#                 625,761 ratings  —
#                 published 2018
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="5_book_26032825">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="mq1O/o5D7NRbQHIRA8QFgafVuRRt/24YHmgatHwL/WT2mggWLJrHDNp5LBFWXaRKsaPNSvQwAzyIiM3gSUzhVg=="/>
# <input id="book_id" name="book_id" type="hidden" value="26032825"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_26032825"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ZYhe+bzeJLU78A6+cS2iog+JRirJ74d96Tn+TJSkYjgJvxgRHgcPbbrJUL4ktANpGf8ydFAg6ll/2SkYoeN+Cg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="5_book_26032825"/>
# <input id="book_id" name="book_id" type="hidden" value="26032825"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="26032825" data-submit-url="/review/rate/26032825?stars_click=true&amp;wtr_button_id=5_book_26032825" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/52831200-from-blood-and-ash" title="From Blood and Ash (Blood and Ash, #1)"><img alt="From Blood and Ash (Blood and Ash, #1)" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1585598504l/52831200._SX50_.jpg"/></a>
# <a class="bookTitle" href="/book/show/52831200-from-blood-and-ash">From Blood and Ash (Blood and Ash, #1)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/4476934.Jennifer_L_Armentrout" itemprop="url"><span itemprop="name">Jennifer L. Armentrout</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 427 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.30 —
#                 281,880 ratings  —
#                 published 2020
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="6_book_52831200">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="x+XNq8BhgZOS/aUt+XgsctB4vVcZCCeNqMo8XXEMlHir0otDYriqSxPE+y2s4Y25xg7JCYDHSqk+KusJREuISg=="/>
# <input id="book_id" name="book_id" type="hidden" value="52831200"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="6_book_52831200"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="wwhTMOHE57+SH3BmBC33OfRgLmHJrpOKGh0GHX5IDEWvPxXYQx3MZxMmLmZRtFby4hZaP1Bh/q6M/dFJSw8Qdw=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="6_book_52831200"/>
# <input id="book_id" name="book_id" type="hidden" value="52831200"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="52831200" data-submit-url="/review/rate/52831200?stars_click=true&amp;wtr_button_id=6_book_52831200" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/23437156-six-of-crows" title="Six of Crows (Six of Crows, #1)"><img alt="Six of Crows (Six of Crows, #1)" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1651710803l/23437156._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/23437156-six-of-crows">Six of Crows (Six of Crows, #1)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/4575289.Leigh_Bardugo" itemprop="url"><span itemprop="name">Leigh Bardugo</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 426 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.49 —
#                 660,633 ratings  —
#                 published 2015
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="7_book_23437156">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="yX9qTcs8lN79vLqQnyrSyWkdxIfdjBED2W6cWZT5S6ClSCylaeW/BnyF5JDKs3MCf2uw2URDfCdPjksNob5Xkg=="/>
# <input id="book_id" name="book_id" type="hidden" value="23437156"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="7_book_23437156"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="ccS6mXgnQY+spcT6f3M5G5GUi7NlhtNsqNNc2wW2t5Md8/xx2v5qVy2cmvoq6pjQh+L/7fxJvkg+M4uPMPGroQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="7_book_23437156"/>
# <input id="book_id" name="book_id" type="hidden" value="23437156"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="23437156" data-submit-url="/review/rate/23437156?stars_click=true&amp;wtr_button_id=7_book_23437156" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/33385229-they-both-die-at-the-end" title="They Both Die at the End"><img alt="They Both Die at the End" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1494333138l/33385229._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/33385229-they-both-die-at-the-end">They Both Die at the End (Hardcover)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/7577278.Adam_Silvera" itemprop="url"><span itemprop="name">Adam Silvera</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 419 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 3.89 —
#                 442,463 ratings  —
#                 published 2017
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="8_book_33385229">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Z33JZTgY0KgTtOflvdrcgE04EoB7IZ81FiRvyOID5IwLSo+NmsH7cJKNueXoQ31LW05m3uLu8hGAxLic10T4vg=="/>
# <input id="book_id" name="book_id" type="hidden" value="33385229"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="8_book_33385229"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="gdQMVaTv6Xo/lkAG+qlvpKBQl+rFE9mdlzuIGeiO3ynt40q9BjbCor6vHgavMM5vtibjtFzctLkB219N3cnDGw=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="8_book_33385229"/>
# <input id="book_id" name="book_id" type="hidden" value="33385229"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="33385229" data-submit-url="/review/rate/33385229?stars_click=true&amp;wtr_button_id=8_book_33385229" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/50659467-a-court-of-thorns-and-roses" title="A Court of Thorns and Roses (A Court of Thorns and Roses, #1)"><img alt="A Court of Thorns and Roses (A Court of Thorns and Roses, #1)" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1620324329l/50659467._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/50659467-a-court-of-thorns-and-roses">A Court of Thorns and Roses (A Court of Thorns and Roses, #1)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/3433047.Sarah_J_Maas" itemprop="url"><span itemprop="name">Sarah J. Maas</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 408 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.19 —
#                 1,000,718 ratings  —
#                 published 2015
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="9_book_50659467">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Txn4eEkXtZqQ8+fUoBN1R/3Pcd3I97rwa4cR1ZrZxQUjLr6Q686eQhHKudT1itSM67kFg1E419T9Z8aBr57ZNw=="/>
# <input id="book_id" name="book_id" type="hidden" value="50659467"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="9_book_50659467"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="EFQd5+OcOlkQfhEJ2awowhqaoKLb+Rwp7GeH5uubSQR8Y1sPQUURgZFHTwmMNYkJDOzU/EI2cQ16h1Cy3txVNg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="9_book_50659467"/>
# <input id="book_id" name="book_id" type="hidden" value="50659467"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="50659467" data-submit-url="/review/rate/50659467?stars_click=true&amp;wtr_button_id=9_book_50659467" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/41150487-red-white-royal-blue" title="Red, White &amp; Royal Blue"><img alt="Red, White &amp; Royal Blue" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1566742512l/41150487._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/41150487-red-white-royal-blue">Red, White &amp; Royal Blue (Paperback)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/17949486.Casey_McQuiston" itemprop="url"><span itemprop="name">Casey McQuiston</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 407 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.18 —
#                 528,074 ratings  —
#                 published 2019
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="10_book_41150487">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="BN5y9htMGFKXE+GMAedJ7pYu3bA08djBrghMBmntqLRo6TQeuZUzihYqv4xUfuglgFip7q0+teU46JtSXKq0hg=="/>
# <input id="book_id" name="book_id" type="hidden" value="41150487"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="10_book_41150487"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="U2KxionRrw7a4AWWRk5rRIe1QGa/+Z6yIidSvZp8DM8/VfdiKwiE1lvZW5YT18qPkcM0OCY285a0x4XprzsQ/Q=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="10_book_41150487"/>
# <input id="book_id" name="book_id" type="hidden" value="41150487"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="41150487" data-submit-url="/review/rate/41150487?stars_click=true&amp;wtr_button_id=10_book_41150487" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/56732449-the-love-hypothesis" title="The Love Hypothesis"><img alt="The Love Hypothesis" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1611937942l/56732449._SX50_.jpg"/></a>
# <a class="bookTitle" href="/book/show/56732449-the-love-hypothesis">The Love Hypothesis (Paperback)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/21098177.Ali_Hazelwood" itemprop="url"><span itemprop="name">Ali Hazelwood</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 368 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.34 —
#                 503,858 ratings  —
#                 published 2021
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="11_book_56732449">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="y0ALtC2/fiyw9iNJqmM/YfaYRQBNDR9LU9rPKHBfOG2nd01cj2ZV9DHPfUn/+p6q4O4xXtTCcm/FOhh8RRgkXw=="/>
# <input id="book_id" name="book_id" type="hidden" value="56732449"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="11_book_56732449"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Rs7DUQ/T7WBiRUXv//tVDiEbtSzTn74tOAFvNtPDPncq+YW5rQrGuON8G++qYvTFN23BckpQ0wmu4bhi5oQiRQ=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="11_book_56732449"/>
# <input id="book_id" name="book_id" type="hidden" value="56732449"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="56732449" data-submit-url="/review/rate/56732449?stars_click=true&amp;wtr_button_id=11_book_56732449" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/17788401-ugly-love" title="Ugly Love"><img alt="Ugly Love" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1632597571l/17788401._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/17788401-ugly-love">Ugly Love (Kindle Edition)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/5430144.Colleen_Hoover" itemprop="url"><span itemprop="name">Colleen Hoover</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 342 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.25 —
#                 627,107 ratings  —
#                 published 2014
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="12_book_17788401">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="q9/tPMsV6MxTnvS/HIIzk8ZWr0vW+5BgrH5DF38HupjH6KvUaczDFNKnqr9JG5JY0CDbFU80/UQ6npRDSkCmqg=="/>
# <input id="book_id" name="book_id" type="hidden" value="17788401"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="12_book_17788401"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="Tohnxn+9MU7lB4chld95n6T9/q+sIAGINoaYa4ozjRIivyEu3WQalmQ+2SHARthUsouK8TXvbKygZk8/v3SRIA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="12_book_17788401"/>
# <input id="book_id" name="book_id" type="hidden" value="17788401"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="17788401" data-submit-url="/review/rate/17788401?stars_click=true&amp;wtr_button_id=12_book_17788401" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# ...
# </div>
# </span>
#
#
#               (shelved 178 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.28 —
#                 363,824 ratings  —
#                 published 2015
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="47_book_24920901">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="hlb6EUkcylWhl0PNsfMdiUMfddXbblESZK07bXWzkeHqYbz568XhjSCuHc3karxCVWkBi0KhPDbyTew5QPSN0w=="/>
# <input id="book_id" name="book_id" type="hidden" value="24920901"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="47_book_24920901"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="b6hAc2CiFBZStwwflirM5+V/HEpD+p7q0bU1np13VFoDnwabwns/ztOOUh/Ds20s8wloFNo1885HVeLKqDBIaA=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="47_book_24920901"/>
# <input id="book_id" name="book_id" type="hidden" value="24920901"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="24920901" data-submit-url="/review/rate/24920901?stars_click=true&amp;wtr_button_id=47_book_24920901" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/25111004-november-9" title="November 9"><img alt="November 9" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1447138036l/25111004._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/25111004-november-9">November 9 (Paperback)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/5430144.Colleen_Hoover" itemprop="url"><span itemprop="name">Colleen Hoover</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 177 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.33 —
#                 357,611 ratings  —
#                 published 2015
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="48_book_25111004">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="g0kf/bQpP42xW9ggdQ0/ApKz7XmC1Dp8uhka+r2lpf3vflkVFvAUVTBihiAglJ7JhMWZJxsbV1gs+c2uiOK5zw=="/>
# <input id="book_id" name="book_id" type="hidden" value="25111004"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="48_book_25111004"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="8mgAfzm4eI17BTWYyqKhrwP3XZFNLMbcC63dbUGTOBieX0aXm2FTVfo8a5ifOwBkFYEpz9Tjq/idTQo5dNQkKg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="48_book_25111004"/>
# <input id="book_id" name="book_id" type="hidden" value="25111004"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="25111004" data-submit-url="/review/rate/25111004?stars_click=true&amp;wtr_button_id=48_book_25111004" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/54659771-neon-gods" title="Neon Gods (Dark Olympus, #1)"><img alt="Neon Gods (Dark Olympus, #1)" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1610505010l/54659771._SX50_.jpg"/></a>
# <a class="bookTitle" href="/book/show/54659771-neon-gods">Neon Gods (Dark Olympus, #1)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/5398028.Katee_Robert" itemprop="url"><span itemprop="name">Katee Robert</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 173 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 3.74 —
#                 83,280 ratings  —
#                 published 2021
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="49_book_54659771">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="D6QxaQPuNYKGK8z55vZMwCCYiWmvS+OQ8o28kdXCsOFjk3eBoTceWgcSkvmzb+0LNu79NzaEjrRkbWvF4IWs0w=="/>
# <input id="book_id" name="book_id" type="hidden" value="54659771"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="49_book_54659771"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="PtKWV0QEhzM5I9l4Tr8DqPJK4QByjz9+k+RTr7KHvvhS5dC/5t2s67gah3gbJqJj5DyVXutAUloFBIT7h8Ciyg=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="49_book_54659771"/>
# <input id="book_id" name="book_id" type="hidden" value="54659771"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="54659771" data-submit-url="/review/rate/54659771?stars_click=true&amp;wtr_button_id=49_book_54659771" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="padding-top: 10px;">
# <div class="left" style="width: 75%;">
# <a class="leftAlignedImage" href="/book/show/10507293-the-selection" title="The Selection (The Selection, #1)"><img alt="The Selection (The Selection, #1)" src="https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1322103400l/10507293._SY75_.jpg"/></a>
# <a class="bookTitle" href="/book/show/10507293-the-selection">The Selection (The Selection, #1)</a>
# <br/>
# <span class="by">by</span>
# <span itemprop="author" itemscope="" itemtype="http://schema.org/Person">
# <div class="authorName__container">
# <a class="authorName" href="https://www.goodreads.com/author/show/2987125.Kiera_Cass" itemprop="url"><span itemprop="name">Kiera Cass</span></a> <span class="greyText">(Goodreads Author)</span>
# </div>
# </span>
#
#
#               (shelved 173 times as <em>booktok</em>)
#
#               <br/>
# <span class="greyText smallText">
#                 avg rating 4.10 —
#                 1,245,222 ratings  —
#                 published 2012
#               </span>
# </div>
# <div class="right">
# <div class="wtrButtonContainer wtrSignedOut" id="50_book_10507293">
# <div class="wtrUp wtrLeft">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="3xgKiVSNwEWufJ3sOs6twNaq/MyvFDx/fhhjzEYXJfezL0xh9lTrnS9Fw+xvVwwLwNyIkjbbUVvo+LSYc1A5xQ=="/>
# <input id="book_id" name="book_id" type="hidden" value="10507293"/>
# <input id="name" name="name" type="hidden" value="to-read"/>
# <input id="unique_id" name="unique_id" type="hidden" value="50_book_10507293"/>
# <input id="wtr_new" name="wtr_new" type="hidden" value="true"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input class="wtrLeftUpRef" id="ref" name="ref" type="hidden" value=""/>
# <input class="wtrExisting" id="existing_review" name="existing_review" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# <button class="wtrToRead" type="submit">
# <span class="progressTrigger">Want to Read</span>
# <span class="progressIndicator">saving…</span>
# </button>
# </form>
# </div>
# <div class="wtrRight wtrUp">
# <form accept-charset="UTF-8" action="/shelf/add_to_shelf" class="hiddenShelfForm" method="post"><input name="utf8" type="hidden" value="✓"/><input name="authenticity_token" type="hidden" value="iRUHulKt53CCTOkXblPWq1nQPpACS5oUUUdza2TSfBnlIkFS8HTMqAN1txc7yndgT6ZKzpuE9zDHp6Q/UZVgKw=="/>
# <input id="unique_id" name="unique_id" type="hidden" value="50_book_10507293"/>
# <input id="book_id" name="book_id" type="hidden" value="10507293"/>
# <input id="a" name="a" type="hidden"/>
# <input id="name" name="name" type="hidden"/>
# <input id="from_choice" name="from_choice" type="hidden" value="false"/>
# <input id="from_home_module" name="from_home_module" type="hidden" value="false"/>
# <input id="page_url" name="page_url" type="hidden"/>
# </form>
# <button class="wtrShelfButton"></button>
# </div>
# <div class="ratingStars wtrRating">
# <div class="starsErrorTooltip hidden">
# Error rating book. Refresh and try again.
# </div>
# <div class="myRating uitext greyText">Rate this book</div>
# <div class="clearRating uitext">Clear rating</div>
# <div class="stars" data-rating="0" data-resource-id="10507293" data-submit-url="/review/rate/10507293?stars_click=true&amp;wtr_button_id=50_book_10507293" data-user-id="0"><a class="star off" href="#" ref="" title="did not like it">1 of 5 stars</a><a class="star off" href="#" ref="" title="it was ok">2 of 5 stars</a><a class="star off" href="#" ref="" title="liked it">3 of 5 stars</a><a class="star off" href="#" ref="" title="really liked it">4 of 5 stars</a><a class="star off" href="#" ref="" title="it was amazing">5 of 5 stars</a></div>
# </div>
# </div>
# </div>
# <div class="clear"></div>
# </div>, <div class="elementList" style="width: 100%">
# <div style="float: left; padding-right: 10px">
# <div class="videoThumbnail" data-goodreads-id="190579" data-source="youtube" data-source-id="0Q5pqyaWrxE"><a href="/videos/190579-the-simulation-game-by-j-w-lynne---the-prologue"><img alt="The Simulation Game by J.W. Lynne - The Prologue" src="https://i.ytimg.com/vi/0Q5pqyaWrxE/default.jpg"/></a><a class="playIcon" href="/videos/190579-the-simulation-game-by-j-w-lynne---the-prologue"></a></div>
# </div>
# <a class="videoTitle" href="/videos/190579-the-simulation-game-by-j-w-lynne---the-prologue">The Simulation Game by J.W. Lynne - The Prologue</a>
# <br class="clear"/>
# </div>, <div class="elementList" style="width: 100%">
# <div style="float: left; padding-right: 10px">
# <div class="videoThumbnail" data-goodreads-id="181259" data-source="youtube" data-source-id="0vEVh8_KHGI"><a href="/videos/181259-august-2021-book-reveal"><img alt="August 2021 Book Reveal" src="https://i.ytimg.com/vi/0vEVh8_KHGI/default.jpg"/></a><a class="playIcon" href="/videos/181259-august-2021-book-reveal"></a></div>
# </div>
# <a class="videoTitle" href="/videos/181259-august-2021-book-reveal">August 2021 Book Reveal</a>
# <br class="clear"/>
# </div>]

# %% [markdown]
# ### get titles of first page

# %%
#https://www.geeksforgeeks.org/difference-between-find-and-find_all-in-beautifulsoup-python/
#https://www.adamsmith.haus/python/answers/how-to-build-a-pandas-dataframe-with-a-for-loop-in-python
books = []
for card in cards:
    books.append(str(card.find('a', {'class': 'bookTitle'})))

# %%
books
# Out:
# ['<a class="bookTitle" href="/book/show/32620332-the-seven-husbands-of-evelyn-hugo">The Seven Husbands of Evelyn Hugo (Hardcover)</a>',
#  '<a class="bookTitle" href="/book/show/27362503-it-ends-with-us">It Ends with Us (Kindle Edition)</a>',
#  '<a class="bookTitle" href="/book/show/13623848-the-song-of-achilles">The Song of Achilles (Paperback)</a>',
#  '<a class="bookTitle" href="/book/show/50623864-the-invisible-life-of-addie-larue">The Invisible Life of Addie LaRue (Hardcover)</a>',
#  '<a class="bookTitle" href="/book/show/26032825-the-cruel-prince">The Cruel Prince (The Folk of the Air, #1)</a>',
#  '<a class="bookTitle" href="/book/show/52831200-from-blood-and-ash">From Blood and Ash (Blood and Ash, #1)</a>',
#  '<a class="bookTitle" href="/book/show/23437156-six-of-crows">Six of Crows (Six of Crows, #1)</a>',
#  '<a class="bookTitle" href="/book/show/33385229-they-both-die-at-the-end">They Both Die at the End (Hardcover)</a>',
#  '<a class="bookTitle" href="/book/show/50659467-a-court-of-thorns-and-roses">A Court of Thorns and Roses (A Court of Thorns and Roses, #1)</a>',
#  '<a class="bookTitle" href="/book/show/41150487-red-white-royal-blue">Red, White &amp; Royal Blue (Paperback)</a>',
#  '<a class="bookTitle" href="/book/show/56732449-the-love-hypothesis">The Love Hypothesis (Paperback)</a>',
#  '<a class="bookTitle" href="/book/show/17788401-ugly-love">Ugly Love (Kindle Edition)</a>',
#  '<a class="bookTitle" href="/book/show/16143347-we-were-liars">We Were Liars (Kindle Edition)</a>',
#  '<a class="bookTitle" href="/book/show/54985743-people-we-meet-on-vacation">People We Meet on Vacation (Paperback)</a>',
#  '<a class="bookTitle" href="/book/show/54189398-the-spanish-love-deception">The Spanish Love Deception (ebook)</a>',
#  '<a class="bookTitle" href="/book/show/25883848-the-hating-game">The Hating Game (ebook)</a>',
#  '<a class="bookTitle" href="/book/show/52867387-beach-read">Beach Read (Paperback)</a>',
#  '<a class="bookTitle" href="/book/show/10194157-shadow-and-bone">Shadow and Bone (The Shadow and Bone Trilogy, #1)</a>',
#  '<a class="bookTitle" href="/book/show/52439531-the-inheritance-games">The Inheritance Games (The Inheritance Games, #1)</a>',
#  '<a class="bookTitle" href="/book/show/50892212-these-violent-delights">These Violent Delights (These Violent Delights #1)</a>',
#  '<a class="bookTitle" href="/book/show/42201431-the-unhoneymooners">The Unhoneymooners (Paperback)</a>',
#  '<a class="bookTitle" href="/book/show/59344312-verity">Verity (ebook)</a>',
#  '<a class="bookTitle" href="/book/show/40024139-serpent-dove">Serpent &amp; Dove (Serpent &amp; Dove, #1)</a>',
#  '<a class="bookTitle" href="/book/show/27883214-caraval">Caraval (Caraval, #1)</a>',
#  '<a class="bookTitle" href="/book/show/35959740-circe">Circe (Hardcover)</a>',
#  '<a class="bookTitle" href="/book/show/52735921-kingdom-of-the-wicked">Kingdom of the Wicked (Kingdom of the Wicked, #1)</a>',
#  '<a class="bookTitle" href="/book/show/41021967-punk-57">Punk 57 (Kindle Edition)</a>',
#  '<a class="bookTitle" href="/book/show/35702241-the-shadows-between-us">The Shadows Between Us (The Shadows Between Us, #1)</a>',
#  '<a class="bookTitle" href="/book/show/35796008-dance-of-thieves">Dance of Thieves (Dance of Thieves, #1)</a>',
#  '<a class="bookTitle" href="/book/show/55215339-a-touch-of-darkness">A Touch of Darkness (Hades &amp; Persephone, #1)</a>',
#  '<a class="bookTitle" href="/book/show/10429045-shatter-me">Shatter Me (Shatter Me, #1)</a>',
#  '<a class="bookTitle" href="/book/show/40916679-a-good-girl-s-guide-to-murder">A Good Girl\'s Guide to Murder (A Good Girl\'s Guide to Murder, #1)</a>',
#  '<a class="bookTitle" href="/book/show/22328546-red-queen">Red Queen (Red Queen, #1)</a>',
#  '<a class="bookTitle" href="/book/show/52578297-the-midnight-library">The Midnight Library (Hardcover)</a>',
#  '<a class="bookTitle" href="/book/show/44778083-house-of-earth-and-blood">House of Earth and Blood (Crescent City, #1)</a>',
#  '<a class="bookTitle" href="/book/show/7896527-throne-of-glass">Throne of Glass (Throne of Glass, #1)</a>',
#  '<a class="bookTitle" href="/book/show/36492488-we-hunt-the-flame">We Hunt the Flame (Sands of Arawiya, #1)</a>',
#  '<a class="bookTitle" href="/book/show/33643994-daughter-of-the-pirate-king">Daughter of the Pirate King (Daughter of the Pirate King, #1)</a>',
#  '<a class="bookTitle" href="/book/show/40597810-daisy-jones-the-six">Daisy Jones &amp; The Six (Hardcover)</a>',
#  '<a class="bookTitle" href="/book/show/50659468-a-court-of-mist-and-fury">A Court of Mist and Fury (A Court of Thorns and Roses, #2)</a>',
#  '<a class="bookTitle" href="/book/show/41057294-normal-people">Normal People (Hardcover)</a>',
#  '<a class="bookTitle" href="/book/show/40275288-the-priory-of-the-orange-tree">The Priory of the Orange Tree (Kindle Edition)</a>',
#  '<a class="bookTitle" href="/book/show/58679358-one-of-us-is-lying">One of Us Is Lying (One of Us is Lying, #1)</a>',
#  '<a class="bookTitle" href="/book/show/22299763-crooked-kingdom">Crooked Kingdom (Six of Crows, #2)</a>',
#  '<a class="bookTitle" href="/book/show/50520939-the-atlas-six">The Atlas Six (The Atlas, #1)</a>',
#  '<a class="bookTitle" href="/book/show/34499221-to-kill-a-kingdom">To Kill a Kingdom (Hardcover)</a>',
#  '<a class="bookTitle" href="/book/show/24920901-the-deal">The Deal (Off-Campus, #1)</a>',
#  '<a class="bookTitle" href="/book/show/25111004-november-9">November 9 (Paperback)</a>',
#  '<a class="bookTitle" href="/book/show/54659771-neon-gods">Neon Gods (Dark Olympus, #1)</a>',
#  '<a class="bookTitle" href="/book/show/10507293-the-selection">The Selection (The Selection, #1)</a>',
#  'None',
#  'None']

# %%
#https://www.codegrepper.com/code-examples/html/regex+to+remove+html+tags+python
titles = [re.sub('<.*?>', '', x) for x in books]
titles
# Out:
# ['The Seven Husbands of Evelyn Hugo (Hardcover)',
#  'It Ends with Us (Kindle Edition)',
#  'The Song of Achilles (Paperback)',
#  'The Invisible Life of Addie LaRue (Hardcover)',
#  'The Cruel Prince (The Folk of the Air, #1)',
#  'From Blood and Ash (Blood and Ash, #1)',
#  'Six of Crows (Six of Crows, #1)',
#  'They Both Die at the End (Hardcover)',
#  'A Court of Thorns and Roses (A Court of Thorns and Roses, #1)',
#  'Red, White &amp; Royal Blue (Paperback)',
#  'The Love Hypothesis (Paperback)',
#  'Ugly Love (Kindle Edition)',
#  'We Were Liars (Kindle Edition)',
#  'People We Meet on Vacation (Paperback)',
#  'The Spanish Love Deception (ebook)',
#  'The Hating Game (ebook)',
#  'Beach Read (Paperback)',
#  'Shadow and Bone (The Shadow and Bone Trilogy, #1)',
#  'The Inheritance Games (The Inheritance Games, #1)',
#  'These Violent Delights (These Violent Delights #1)',
#  'The Unhoneymooners (Paperback)',
#  'Verity (ebook)',
#  'Serpent &amp; Dove (Serpent &amp; Dove, #1)',
#  'Caraval (Caraval, #1)',
#  'Circe (Hardcover)',
#  'Kingdom of the Wicked (Kingdom of the Wicked, #1)',
#  'Punk 57 (Kindle Edition)',
#  'The Shadows Between Us (The Shadows Between Us, #1)',
#  'Dance of Thieves (Dance of Thieves, #1)',
#  'A Touch of Darkness (Hades &amp; Persephone, #1)',
#  'Shatter Me (Shatter Me, #1)',
#  "A Good Girl's Guide to Murder (A Good Girl's Guide to Murder, #1)",
#  'Red Queen (Red Queen, #1)',
#  'The Midnight Library (Hardcover)',
#  'House of Earth and Blood (Crescent City, #1)',
#  'Throne of Glass (Throne of Glass, #1)',
#  'We Hunt the Flame (Sands of Arawiya, #1)',
#  'Daughter of the Pirate King (Daughter of the Pirate King, #1)',
#  'Daisy Jones &amp; The Six (Hardcover)',
#  'A Court of Mist and Fury (A Court of Thorns and Roses, #2)',
#  'Normal People (Hardcover)',
#  'The Priory of the Orange Tree (Kindle Edition)',
#  'One of Us Is Lying (One of Us is Lying, #1)',
#  'Crooked Kingdom (Six of Crows, #2)',
#  'The Atlas Six (The Atlas, #1)',
#  'To Kill a Kingdom (Hardcover)',
#  'The Deal (Off-Campus, #1)',
#  'November 9 (Paperback)',
#  'Neon Gods (Dark Olympus, #1)',
#  'The Selection (The Selection, #1)',
#  'None',
#  'None']

# %% [markdown]
# ### get URLs of first page

# %%
#https://stackoverflow.com/questions/3075550/how-can-i-get-href-links-from-html-using-python

#when just using href attr, returned duplicates, so had to add class attr
#https://pytutorial.com/beautifulsoup-attribute#beautifulsoup-find-all-by-multiple-attributes

hrefs = []
for link in soup.findAll('a', attrs={'class': 'bookTitle', 'href': re.compile("^/book/show/")}) :
    hrefs.append(link.get('href'))
    
hrefs
# Out:
# ['/book/show/32620332-the-seven-husbands-of-evelyn-hugo',
#  '/book/show/27362503-it-ends-with-us',
#  '/book/show/13623848-the-song-of-achilles',
#  '/book/show/50623864-the-invisible-life-of-addie-larue',
#  '/book/show/26032825-the-cruel-prince',
#  '/book/show/52831200-from-blood-and-ash',
#  '/book/show/23437156-six-of-crows',
#  '/book/show/33385229-they-both-die-at-the-end',
#  '/book/show/50659467-a-court-of-thorns-and-roses',
#  '/book/show/41150487-red-white-royal-blue',
#  '/book/show/56732449-the-love-hypothesis',
#  '/book/show/17788401-ugly-love',
#  '/book/show/16143347-we-were-liars',
#  '/book/show/54985743-people-we-meet-on-vacation',
#  '/book/show/54189398-the-spanish-love-deception',
#  '/book/show/25883848-the-hating-game',
#  '/book/show/52867387-beach-read',
#  '/book/show/10194157-shadow-and-bone',
#  '/book/show/52439531-the-inheritance-games',
#  '/book/show/50892212-these-violent-delights',
#  '/book/show/42201431-the-unhoneymooners',
#  '/book/show/59344312-verity',
#  '/book/show/40024139-serpent-dove',
#  '/book/show/27883214-caraval',
#  '/book/show/35959740-circe',
#  '/book/show/52735921-kingdom-of-the-wicked',
#  '/book/show/41021967-punk-57',
#  '/book/show/35702241-the-shadows-between-us',
#  '/book/show/35796008-dance-of-thieves',
#  '/book/show/55215339-a-touch-of-darkness',
#  '/book/show/10429045-shatter-me',
#  '/book/show/40916679-a-good-girl-s-guide-to-murder',
#  '/book/show/22328546-red-queen',
#  '/book/show/52578297-the-midnight-library',
#  '/book/show/44778083-house-of-earth-and-blood',
#  '/book/show/7896527-throne-of-glass',
#  '/book/show/36492488-we-hunt-the-flame',
#  '/book/show/33643994-daughter-of-the-pirate-king',
#  '/book/show/40597810-daisy-jones-the-six',
#  '/book/show/50659468-a-court-of-mist-and-fury',
#  '/book/show/41057294-normal-people',
#  '/book/show/40275288-the-priory-of-the-orange-tree',
#  '/book/show/58679358-one-of-us-is-lying',
#  '/book/show/22299763-crooked-kingdom',
#  '/book/show/50520939-the-atlas-six',
#  '/book/show/34499221-to-kill-a-kingdom',
#  '/book/show/24920901-the-deal',
#  '/book/show/25111004-november-9',
#  '/book/show/54659771-neon-gods',
#  '/book/show/10507293-the-selection']

# %%
#https://towardsdatascience.com/scraping-multiple-urls-with-python-tutorial-2b74432d085f
string = 'https://www.goodreads.com'
urls = [string + s for s in hrefs]
urls
# Out:
# ['https://www.goodreads.com/book/show/32620332-the-seven-husbands-of-evelyn-hugo',
#  'https://www.goodreads.com/book/show/27362503-it-ends-with-us',
#  'https://www.goodreads.com/book/show/13623848-the-song-of-achilles',
#  'https://www.goodreads.com/book/show/50623864-the-invisible-life-of-addie-larue',
#  'https://www.goodreads.com/book/show/26032825-the-cruel-prince',
#  'https://www.goodreads.com/book/show/52831200-from-blood-and-ash',
#  'https://www.goodreads.com/book/show/23437156-six-of-crows',
#  'https://www.goodreads.com/book/show/33385229-they-both-die-at-the-end',
#  'https://www.goodreads.com/book/show/50659467-a-court-of-thorns-and-roses',
#  'https://www.goodreads.com/book/show/41150487-red-white-royal-blue',
#  'https://www.goodreads.com/book/show/56732449-the-love-hypothesis',
#  'https://www.goodreads.com/book/show/17788401-ugly-love',
#  'https://www.goodreads.com/book/show/16143347-we-were-liars',
#  'https://www.goodreads.com/book/show/54985743-people-we-meet-on-vacation',
#  'https://www.goodreads.com/book/show/54189398-the-spanish-love-deception',
#  'https://www.goodreads.com/book/show/25883848-the-hating-game',
#  'https://www.goodreads.com/book/show/52867387-beach-read',
#  'https://www.goodreads.com/book/show/10194157-shadow-and-bone',
#  'https://www.goodreads.com/book/show/52439531-the-inheritance-games',
#  'https://www.goodreads.com/book/show/50892212-these-violent-delights',
#  'https://www.goodreads.com/book/show/42201431-the-unhoneymooners',
#  'https://www.goodreads.com/book/show/59344312-verity',
#  'https://www.goodreads.com/book/show/40024139-serpent-dove',
#  'https://www.goodreads.com/book/show/27883214-caraval',
#  'https://www.goodreads.com/book/show/35959740-circe',
#  'https://www.goodreads.com/book/show/52735921-kingdom-of-the-wicked',
#  'https://www.goodreads.com/book/show/41021967-punk-57',
#  'https://www.goodreads.com/book/show/35702241-the-shadows-between-us',
#  'https://www.goodreads.com/book/show/35796008-dance-of-thieves',
#  'https://www.goodreads.com/book/show/55215339-a-touch-of-darkness',
#  'https://www.goodreads.com/book/show/10429045-shatter-me',
#  'https://www.goodreads.com/book/show/40916679-a-good-girl-s-guide-to-murder',
#  'https://www.goodreads.com/book/show/22328546-red-queen',
#  'https://www.goodreads.com/book/show/52578297-the-midnight-library',
#  'https://www.goodreads.com/book/show/44778083-house-of-earth-and-blood',
#  'https://www.goodreads.com/book/show/7896527-throne-of-glass',
#  'https://www.goodreads.com/book/show/36492488-we-hunt-the-flame',
#  'https://www.goodreads.com/book/show/33643994-daughter-of-the-pirate-king',
#  'https://www.goodreads.com/book/show/40597810-daisy-jones-the-six',
#  'https://www.goodreads.com/book/show/50659468-a-court-of-mist-and-fury',
#  'https://www.goodreads.com/book/show/41057294-normal-people',
#  'https://www.goodreads.com/book/show/40275288-the-priory-of-the-orange-tree',
#  'https://www.goodreads.com/book/show/58679358-one-of-us-is-lying',
#  'https://www.goodreads.com/book/show/22299763-crooked-kingdom',
#  'https://www.goodreads.com/book/show/50520939-the-atlas-six',
#  'https://www.goodreads.com/book/show/34499221-to-kill-a-kingdom',
#  'https://www.goodreads.com/book/show/24920901-the-deal',
#  'https://www.goodreads.com/book/show/25111004-november-9',
#  'https://www.goodreads.com/book/show/54659771-neon-gods',
#  'https://www.goodreads.com/book/show/10507293-the-selection']

# %% [markdown]
# ### get number of times shelved as "booktok"

# %%
shelved_booktok = []
for card in cards:
    shelved_booktok.append(str(card.find(string=re.compile("shelved"))))
    
shelved_booktok
# Out:
# ['\n\n\n              (shelved 629 times as ',
#  '\n\n\n              (shelved 571 times as ',
#  '\n\n\n              (shelved 569 times as ',
#  '\n\n\n              (shelved 469 times as ',
#  '\n\n\n              (shelved 450 times as ',
#  '\n\n\n              (shelved 427 times as ',
#  '\n\n\n              (shelved 426 times as ',
#  '\n\n\n              (shelved 419 times as ',
#  '\n\n\n              (shelved 408 times as ',
#  '\n\n\n              (shelved 407 times as ',
#  '\n\n\n              (shelved 368 times as ',
#  '\n\n\n              (shelved 342 times as ',
#  '\n\n\n              (shelved 329 times as ',
#  '\n\n\n              (shelved 328 times as ',
#  '\n\n\n              (shelved 314 times as ',
#  '\n\n\n              (shelved 312 times as ',
#  '\n\n\n              (shelved 309 times as ',
#  '\n\n\n              (shelved 299 times as ',
#  '\n\n\n              (shelved 295 times as ',
#  '\n\n\n              (shelved 293 times as ',
#  '\n\n\n              (shelved 289 times as ',
#  '\n\n\n              (shelved 287 times as ',
#  '\n\n\n              (shelved 279 times as ',
#  '\n\n\n              (shelved 276 times as ',
#  '\n\n\n              (shelved 270 times as ',
#  '\n\n\n              (shelved 264 times as ',
#  '\n\n\n              (shelved 261 times as ',
#  '\n\n\n              (shelved 260 times as ',
#  '\n\n\n              (shelved 258 times as ',
#  '\n\n\n              (shelved 247 times as ',
#  '\n\n\n              (shelved 240 times as ',
#  '\n\n\n              (shelved 237 times as ',
#  '\n\n\n              (shelved 237 times as ',
#  '\n\n\n              (shelved 231 times as ',
#  '\n\n\n              (shelved 231 times as ',
#  '\n\n\n              (shelved 222 times as ',
#  '\n\n\n              (shelved 220 times as ',
#  '\n\n\n              (shelved 213 times as ',
#  '\n\n\n              (shelved 213 times as ',
#  '\n\n\n              (shelved 202 times as ',
#  '\n\n\n              (shelved 190 times as ',
#  '\n\n\n              (shelved 188 times as ',
#  '\n\n\n              (shelved 187 times as ',
#  '\n\n\n              (shelved 185 times as ',
#  '\n\n\n              (shelved 180 times as ',
#  '\n\n\n              (shelved 178 times as ',
#  '\n\n\n              (shelved 178 times as ',
#  '\n\n\n              (shelved 177 times as ',
#  '\n\n\n              (shelved 173 times as ',
#  '\n\n\n              (shelved 173 times as ',
#  'None',
#  'None']

# %%
#remove all but number of times shelved as booktok
#https://stackoverflow.com/questions/1249388/removing-all-non-numeric-characters-from-string-in-python
shelved_booktok = [re.sub("[^0-9]", "", x) for x in shelved_booktok]
shelved_booktok
# Out:
# ['629',
#  '571',
#  '569',
#  '469',
#  '450',
#  '427',
#  '426',
#  '419',
#  '408',
#  '407',
#  '368',
#  '342',
#  '329',
#  '328',
#  '314',
#  '312',
#  '309',
#  '299',
#  '295',
#  '293',
#  '289',
#  '287',
#  '279',
#  '276',
#  '270',
#  '264',
#  '261',
#  '260',
#  '258',
#  '247',
#  '240',
#  '237',
#  '237',
#  '231',
#  '231',
#  '222',
#  '220',
#  '213',
#  '213',
#  '202',
#  '190',
#  '188',
#  '187',
#  '185',
#  '180',
#  '178',
#  '178',
#  '177',
#  '173',
#  '173',
#  '',
#  '']

# %%
#remove empty values from list
#https://www.geeksforgeeks.org/python-remove-empty-strings-from-list-of-strings/
while("" in shelved_booktok) :
    shelved_booktok.remove("")
    
shelved_booktok
# Out:
# ['629',
#  '571',
#  '569',
#  '469',
#  '450',
#  '427',
#  '426',
#  '419',
#  '408',
#  '407',
#  '368',
#  '342',
#  '329',
#  '328',
#  '314',
#  '312',
#  '309',
#  '299',
#  '295',
#  '293',
#  '289',
#  '287',
#  '279',
#  '276',
#  '270',
#  '264',
#  '261',
#  '260',
#  '258',
#  '247',
#  '240',
#  '237',
#  '237',
#  '231',
#  '231',
#  '222',
#  '220',
#  '213',
#  '213',
#  '202',
#  '190',
#  '188',
#  '187',
#  '185',
#  '180',
#  '178',
#  '178',
#  '177',
#  '173',
#  '173']

# %% [markdown]
# ### get authors

# %%
authors = []
for card in cards:
    authors.append(str(card.find('span', {'itemprop': 'name'})))
    
authors
# Out:
# ['<span itemprop="name">Taylor Jenkins Reid</span>',
#  '<span itemprop="name">Colleen Hoover</span>',
#  '<span itemprop="name">Madeline Miller</span>',
#  '<span itemprop="name">V.E. Schwab</span>',
#  '<span itemprop="name">Holly Black</span>',
#  '<span itemprop="name">Jennifer L. Armentrout</span>',
#  '<span itemprop="name">Leigh Bardugo</span>',
#  '<span itemprop="name">Adam Silvera</span>',
#  '<span itemprop="name">Sarah J. Maas</span>',
#  '<span itemprop="name">Casey McQuiston</span>',
#  '<span itemprop="name">Ali Hazelwood</span>',
#  '<span itemprop="name">Colleen Hoover</span>',
#  '<span itemprop="name">E. Lockhart</span>',
#  '<span itemprop="name">Emily Henry</span>',
#  '<span itemprop="name">Elena  Armas</span>',
#  '<span itemprop="name">Sally  Thorne</span>',
#  '<span itemprop="name">Emily Henry</span>',
#  '<span itemprop="name">Leigh Bardugo</span>',
#  '<span itemprop="name">Jennifer Lynn Barnes</span>',
#  '<span itemprop="name">Chloe Gong</span>',
#  '<span itemprop="name">Christina Lauren</span>',
#  '<span itemprop="name">Colleen Hoover</span>',
#  '<span itemprop="name">Shelby Mahurin</span>',
#  '<span itemprop="name">Stephanie Garber</span>',
#  '<span itemprop="name">Madeline Miller</span>',
#  '<span itemprop="name">Kerri Maniscalco</span>',
#  '<span itemprop="name">Penelope Douglas</span>',
#  '<span itemprop="name">Tricia Levenseller</span>',
#  '<span itemprop="name">Mary E. Pearson</span>',
#  '<span itemprop="name">Scarlett St. Clair</span>',
#  '<span itemprop="name">Tahereh Mafi</span>',
#  '<span itemprop="name">Holly  Jackson</span>',
#  '<span itemprop="name">Victoria Aveyard</span>',
#  '<span itemprop="name">Matt Haig</span>',
#  '<span itemprop="name">Sarah J. Maas</span>',
#  '<span itemprop="name">Sarah J. Maas</span>',
#  '<span itemprop="name">Hafsah Faizal</span>',
#  '<span itemprop="name">Tricia Levenseller</span>',
#  '<span itemprop="name">Taylor Jenkins Reid</span>',
#  '<span itemprop="name">Sarah J. Maas</span>',
#  '<span itemprop="name">Sally Rooney</span>',
#  '<span itemprop="name">Samantha Shannon</span>',
#  '<span itemprop="name">Karen M. McManus</span>',
#  '<span itemprop="name">Leigh Bardugo</span>',
#  '<span itemprop="name">Olivie Blake</span>',
#  '<span itemprop="name">Alexandra Christo</span>',
#  '<span itemprop="name">Elle Kennedy</span>',
#  '<span itemprop="name">Colleen Hoover</span>',
#  '<span itemprop="name">Katee Robert</span>',
#  '<span itemprop="name">Kiera Cass</span>',
#  'None',
#  'None']

# %%
#https://www.codegrepper.com/code-examples/html/regex+to+remove+html+tags+python
authors = [re.sub('<.*?>', '', x) for x in authors]
authors
# Out:
# ['Taylor Jenkins Reid',
#  'Colleen Hoover',
#  'Madeline Miller',
#  'V.E. Schwab',
#  'Holly Black',
#  'Jennifer L. Armentrout',
#  'Leigh Bardugo',
#  'Adam Silvera',
#  'Sarah J. Maas',
#  'Casey McQuiston',
#  'Ali Hazelwood',
#  'Colleen Hoover',
#  'E. Lockhart',
#  'Emily Henry',
#  'Elena  Armas',
#  'Sally  Thorne',
#  'Emily Henry',
#  'Leigh Bardugo',
#  'Jennifer Lynn Barnes',
#  'Chloe Gong',
#  'Christina Lauren',
#  'Colleen Hoover',
#  'Shelby Mahurin',
#  'Stephanie Garber',
#  'Madeline Miller',
#  'Kerri Maniscalco',
#  'Penelope Douglas',
#  'Tricia Levenseller',
#  'Mary E. Pearson',
#  'Scarlett St. Clair',
#  'Tahereh Mafi',
#  'Holly  Jackson',
#  'Victoria Aveyard',
#  'Matt Haig',
#  'Sarah J. Maas',
#  'Sarah J. Maas',
#  'Hafsah Faizal',
#  'Tricia Levenseller',
#  'Taylor Jenkins Reid',
#  'Sarah J. Maas',
#  'Sally Rooney',
#  'Samantha Shannon',
#  'Karen M. McManus',
#  'Leigh Bardugo',
#  'Olivie Blake',
#  'Alexandra Christo',
#  'Elle Kennedy',
#  'Colleen Hoover',
#  'Katee Robert',
#  'Kiera Cass',
#  'None',
#  'None']

# %%
#remove none values
#https://www.geeksforgeeks.org/python-remove-empty-strings-from-list-of-strings/
while("None" in authors) :
    authors.remove("None")
    
authors
# Out:
# ['Taylor Jenkins Reid',
#  'Colleen Hoover',
#  'Madeline Miller',
#  'V.E. Schwab',
#  'Holly Black',
#  'Jennifer L. Armentrout',
#  'Leigh Bardugo',
#  'Adam Silvera',
#  'Sarah J. Maas',
#  'Casey McQuiston',
#  'Ali Hazelwood',
#  'Colleen Hoover',
#  'E. Lockhart',
#  'Emily Henry',
#  'Elena  Armas',
#  'Sally  Thorne',
#  'Emily Henry',
#  'Leigh Bardugo',
#  'Jennifer Lynn Barnes',
#  'Chloe Gong',
#  'Christina Lauren',
#  'Colleen Hoover',
#  'Shelby Mahurin',
#  'Stephanie Garber',
#  'Madeline Miller',
#  'Kerri Maniscalco',
#  'Penelope Douglas',
#  'Tricia Levenseller',
#  'Mary E. Pearson',
#  'Scarlett St. Clair',
#  'Tahereh Mafi',
#  'Holly  Jackson',
#  'Victoria Aveyard',
#  'Matt Haig',
#  'Sarah J. Maas',
#  'Sarah J. Maas',
#  'Hafsah Faizal',
#  'Tricia Levenseller',
#  'Taylor Jenkins Reid',
#  'Sarah J. Maas',
#  'Sally Rooney',
#  'Samantha Shannon',
#  'Karen M. McManus',
#  'Leigh Bardugo',
#  'Olivie Blake',
#  'Alexandra Christo',
#  'Elle Kennedy',
#  'Colleen Hoover',
#  'Katee Robert',
#  'Kiera Cass']
